# %%
# !pip install kaggle  #  chack instlation of kaggle

# %%
# !mkdir ~/.kaggle    # make new folder (kaggle)

# %%
# !cp kaggle.json ~/.kaggle  # move file to my kaggle folder

# %%
# !chmod 600 ~/.kaggle/kaggle.json  # change accesing type

# %%
# !kaggle datasets list # make connection
# Out:
# ref                                                            title                                               size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------------  -------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# thedrcat/daigt-v2-train-dataset                                DAIGT V2 Train Dataset                              29MB  2023-11-16 01:38:36            860        101  1.0
# carlmcbrideellis/llm-7-prompt-training-dataset                 LLM: 7 prompt training dataset                      41MB  2023-11-15 07:32:56           1298        103  1.0
# thedrcat/daigt-proper-train-dataset                            DAIGT Proper Train Dataset                         119MB  2023-11-05 14:03:25           1275        119  1.0
# ...

# %%
# !kaggle datasets download -d msambare/fer2013
# Out:
# ...
#  66% 40.0M/60.3M [00:00<00:00, 218MB/s]
# 100% 60.3M/60.3M [00:00<00:00, 215MB/s]

# %%
# !unzip /content/fer2013.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/sad/Training_65242339.jpg
#   inflating: train/sad/Training_65267116.jpg
#   inflating: train/sad/Training_65275626.jpg
#   inflating: train/sad/Training_6529266.jpg
#   inflating: train/sad/Training_65329617.jpg
#   inflating: train/sad/Training_65338712.jpg
#   inflating: train/sad/Training_65338797.jpg
#   inflating: train/sad/Training_65387162.jpg
#   inflating: train/sad/Training_65404494.jpg
#   inflating: train/sad/Training_65426218.jpg
#   inflating: train/sad/Training_65430136.jpg
#   inflating: train/sad/Training_65437377.jpg
#   inflating: train/sad/Training_6545735.jpg
#   inflating: train/sad/Training_65463385.jpg
#   inflating: train/sad/Training_65473985.jpg
#   inflating: train/sad/Training_65502829.jpg
#   inflating: train/sad/Training_65505359.jpg
#   inflating: train/sad/Training_65508578.jpg
#   inflating: train/sad/Training_65516023.jpg
#   inflating: train/sad/Training_65524027.jpg
# ...

# %%
import os   # operation system

# %%
os.listdir('/content/train')
# Out:
# ['happy', 'angry', 'disgust', 'fear', 'neutral', 'sad', 'surprise']

# %%
os.listdir('/content/test')
# Out:
# ['happy', 'angry', 'disgust', 'fear', 'neutral', 'sad', 'surprise']

# %%
os.listdir('/content/test/happy')
# Out:
# ['PublicTest_60884527.jpg',
#  'PrivateTest_86947675.jpg',
#  'PublicTest_32839417.jpg',
#  'PrivateTest_15826714.jpg',
#  'PublicTest_3140321.jpg',
#  'PublicTest_88525502.jpg',
#  'PrivateTest_6518376.jpg',
#  'PublicTest_17302120.jpg',
#  'PrivateTest_37169140.jpg',
#  'PublicTest_64608623.jpg',
#  'PublicTest_24024517.jpg',
#  'PublicTest_69166455.jpg',
#  'PrivateTest_41686494.jpg',
#  'PrivateTest_75009569.jpg',
#  'PublicTest_80753326.jpg',
#  'PrivateTest_63483123.jpg',
#  'PrivateTest_77938501.jpg',
#  'PrivateTest_75418974.jpg',
#  'PublicTest_75764670.jpg',
#  'PublicTest_60696854.jpg',
#  'PublicTest_69207826.jpg',
#  'PrivateTest_79769840.jpg',
#  'PublicTest_17050267.jpg',
#  'PrivateTest_62948921.jpg',
#  'PublicTest_64261256.jpg',
#  'PrivateTest_36531981.jpg',
#  'PrivateTest_2260082.jpg',
#  'PrivateTest_68627917.jpg',
#  'PublicTest_14863387.jpg',
#  'PrivateTest_70427358.jpg',
#  'PrivateTest_45765115.jpg',
#  'PrivateTest_27778676.jpg',
# ...

# %%
os.listdir('/content/train/happy')
# Out:
# ['Training_72363605.jpg',
#  'Training_62299693.jpg',
#  'Training_6152251.jpg',
#  'Training_37587759.jpg',
#  'Training_68978964.jpg',
#  'Training_4276964.jpg',
#  'Training_27749892.jpg',
#  'Training_3610534.jpg',
#  'Training_66815828.jpg',
#  'Training_9961393.jpg',
#  'Training_40227236.jpg',
#  'Training_30403113.jpg',
#  'Training_96588162.jpg',
#  'Training_38887319.jpg',
#  'Training_67391683.jpg',
#  'Training_42588871.jpg',
#  'Training_87118259.jpg',
#  'Training_31611675.jpg',
#  'Training_95372070.jpg',
#  'Training_78098191.jpg',
#  'Training_51702410.jpg',
#  'Training_46295727.jpg',
#  'Training_67049164.jpg',
#  'Training_94257461.jpg',
#  'Training_4751179.jpg',
#  'Training_16942488.jpg',
#  'Training_47307735.jpg',
#  'Training_3478453.jpg',
#  'Training_38756386.jpg',
#  'Training_81717519.jpg',
#  'Training_75920236.jpg',
#  'Training_61614390.jpg',
#  'Training_21654284.jpg',
#  'Training_65761543.jpg',
#  'Training_72094823.jpg',
# ...

# %%
import PIL  # can use open cv as cv2 / image processing

# %%
PIL.Image.open('/content/train/happy/Training_31710337.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=48x48>

# %%
PIL.Image.open('/content/test/happy/PublicTest_79820268.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=48x48>

# %%
import tensorflow as tf

# %%
traning_ds =  tf.keras.utils.image_dataset_from_directory(
    '/content/train',
    color_mode='grayscale',
    image_size=(48, 48),
    batch_size=64,
    label_mode='categorical',
    shuffle=True,



)
# Out:
# Found 28709 files belonging to 7 classes.

# %%
test_ds =  tf.keras.utils.image_dataset_from_directory(
    '/content/test',
    color_mode='grayscale',
    image_size=(48, 48),
    batch_size=64,
    label_mode='categorical',
    shuffle=True,

)
# Out:
# Found 7178 files belonging to 7 classes.

# %%
no_batch=tf.data.experimental.cardinality(test_ds)    # number of batches
Test_ds=test_ds.take(no_batch//5)  # take part for testing
val_ds=test_ds.skip(no_batch//5)   # take for valdation after make model

# %%
from tensorflow.python.data.ops.dataset_ops import AUTOTUNE
AUTOTUNE=tf.data.AUTOTUNE

training_ds = traning_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
Test_ds =Test_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds= val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Rescaling(1/255, input_shape=(48,48,1)),
    tf.keras.layers.RandomFlip(),

    tf.keras.layers.RandomZoom(.3),
    tf.keras.layers.RandomRotation(.3),

    # conveltional layers
    tf.keras.layers.Conv2D(32, (3,3), padding='same',activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(64, (3,3), padding='same',activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(128, (3,3), padding='same',activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D((2,2)),
    tf.keras.layers.Dropout(.25),
    tf.keras.layers.Conv2D(128, (3,3), padding='same',activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(128, (3,3), padding='same',activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(128, (3,3), padding='same',activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D((2,2)),
    tf.keras.layers.Dropout(.25),
    tf.keras.layers.Conv2D(512, (3,3), padding='same',activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(512, (3,3), padding='same',activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(512, (3,3), padding='same',activation='relu'),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D((2,2)),

    # fully connected layer
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(.2),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dropout(.2),
    tf.keras.layers.Dense(7,activation='softmax'),


])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  rescaling_4 (Rescaling)     (None, 48, 48, 1)         0
#
#  random_flip_4 (RandomFlip)  (None, 48, 48, 1)         0
#
#  random_zoom_4 (RandomZoom)  (None, 48, 48, 1)         0
#
#  random_rotation_4 (RandomR  (None, 48, 48, 1)         0
#  otation)
#
#  conv2d_27 (Conv2D)          (None, 48, 48, 32)        320
#
#  batch_normalization_27 (Ba  (None, 48, 48, 32)        128
#  tchNormalization)
#
#  conv2d_28 (Conv2D)          (None, 48, 48, 64)        18496
#
#  batch_normalization_28 (Ba  (None, 48, 48, 64)        256
#  tchNormalization)
#
#  conv2d_29 (Conv2D)          (None, 48, 48, 128)       73856
#
#  batch_normalization_29 (Ba  (None, 48, 48, 128)       512
#  tchNormalization)
#
#  max_pooling2d_9 (MaxPoolin  (None, 24, 24, 128)       0
#  g2D)
#
#  dropout_12 (Dropout)        (None, 24, 24, 128)       0
#
# ...

# %%
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=.0001),loss=tf.keras.losses.CategoricalCrossentropy(from_logits=True),metrics='accuracy')

# %%
history=model.fit(training_ds,epochs=100,validation_data=val_ds)
# Out:
# Epoch 1/100
# 449/449 [==============================] - 56s 113ms/step - loss: 1.8593 - accuracy: 0.2256 - val_loss: 1.9227 - val_accuracy: 0.2473
# Epoch 2/100
# 449/449 [==============================] - 50s 111ms/step - loss: 1.8216 - accuracy: 0.2378 - val_loss: 1.7860 - val_accuracy: 0.2532
# Epoch 3/100
# 449/449 [==============================] - 51s 113ms/step - loss: 1.8128 - accuracy: 0.2459 - val_loss: 1.7664 - val_accuracy: 0.2664
# Epoch 4/100
# 449/449 [==============================] - 50s 111ms/step - loss: 1.7976 - accuracy: 0.2534 - val_loss: 1.7736 - val_accuracy: 0.2667
# Epoch 5/100
# 449/449 [==============================] - 50s 112ms/step - loss: 1.7784 - accuracy: 0.2588 - val_loss: 1.7439 - val_accuracy: 0.2747
# Epoch 6/100
# 449/449 [==============================] - 51s 113ms/step - loss: 1.7528 - accuracy: 0.2787 - val_loss: 1.7557 - val_accuracy: 0.2813
# Epoch 7/100
# ...

# %%
import matplotlib.pyplot as plt

# %%
training_acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

plt.plot(training_acc, label = 'accuracy')
plt.plot(val_acc, label = 'val_accuracy')
plt.legend()

# %%
training_acc = history.history['loss']
val_acc = history.history['val_loss']

plt.plot(training_acc, label = 'loss')
plt.plot(val_acc, label = 'val_loss')
plt.legend()

# %%
model.save('model_optimal.h5')

# %% [markdown]
# Test emotion

# %%
import numpy as np

# %%
emotion_dict = {0: "Angry", 1: "Disgust", 2: "Fear", 3:"Happy", 4:"Neutral", 5: "Sad", 6: "surprise"}

# %%
from keras.preprocessing import image

img = image.load_img("/content/test/angry/PrivateTest_10131363.jpg",target_size = (48,48),color_mode = "grayscale")
img = np.array(img)
plt.imshow(img)
print(img.shape) #prints (48,48) that is the shape of our image

img = np.expand_dims(img,axis = 0) #makes image shape (1,48,48)
img = img.reshape(1,48,48,1)
result = model.predict(img)
result = list(result[0])
print(result)

img_index = result.index(max(result))
print(emotion_dict[img_index])
plt.show()
# Out:
# (48, 48)
# 1/1 [==============================] - 0s 22ms/step
# [0.42712957, 0.08038079, 0.21488746, 0.104168, 0.030382348, 0.085625745, 0.05742613]
# Angry

# %%
train_loss, train_acc = model.evaluate(training_ds)
test_loss, test_acc = model.evaluate(val_ds)

print("fianl train accuracy = {:.2f}, validation accuracy  = {:.2f}".format(train_acc*100, test_acc*100) )
# Out:
# ...
# 91/91 [==============================] - 2s 26ms/step - loss: 1.0762 - accuracy: 0.5976
# fianl train accuracy = 62.93, validation accuracy  = 59.76
